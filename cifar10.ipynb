# %%
# %load_ext autoreload
# %autoreload 2

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from data_manager import ClassficationDataset, mnist_collate
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_path = os.path.expanduser('~/Desktop/My_file/work_工作點滴/2019年/cpr_存摺影像辨識/images/Images')

y_label_list = ['inner', 'cover']

mode = 'train'

# %%
dataset = ClassficationDataset(data_path, 'train', y_label_list)

# %%
y_label = dataset.image_list[0].split('/')[-2]

y_label_index = dataset.y_label_list.index(y_label)

# %%
image = np.array(dataset.__getitem__(0)[0], dtype=np.uint8)

# %%
width = 400
height = 300

input_shape = (-1, 3, width, height)

# %%
image_resize = cv2.resize(image, input_shape[-2:])

# %%
plt.imshow(image)
plt.show()
plt.imshow(image_resize)
plt.show()

# %%
train_loader = DataLoader(
        dataset=mnist_train_dataset,
        batch_size=cfg.train_batch_size,
        shuffle=True,
        collate_fn=mnist_collate
    )
